# %%
# !pip install kafka-python

# %%
import subprocess
import time
import os

os.system("pkill -f emergency_call_simulator.py")
time.sleep(1)


print("Starting Emergency Call Simulator...")
simulator_process = subprocess.Popen(
    ["python", "/home/jovyan/ingestion/kafka/producers/emergency_call_simulator.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    text=True
)

time.sleep(3)
print("Simulator is running in the background!")
# Out:
# Starting Emergency Call Simulator...
# Simulator is running in the background!

# %%
import os
# Free up Spark cores by killing any old background spark-submits
os.system("pkill -9 -f spark-submit")
print("Submitting Spark Streaming Job...")
# !spark-submit --master spark://spark-master:7077 --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.0 /opt/spark/jobs/streaming_processor.py
# Out:
# Submitting Spark Streaming Job...
# :: loading settings :: url = jar:file:/usr/local/spark-3.5.0-bin-hadoop3/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/jovyan/.ivy2/cache
# The jars for the packages stored in: /home/jovyan/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-7b179319-e1b1-49c7-80ba-d4c5232195ec;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.0 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.0 in central
# 	found org.apache.kafka#kafka-clients;3.4.1 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.3 in central
# 	found org.slf4j#slf4j-api;2.0.7 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
# 	found org.apache.hadoop#hadoop-client-api;3.3.4 in central
# ...

# %%
import os
# Kill any background instances of the simulator
os.system("pkill -f emergency_call_simulator.py")
print("Simulator stopped completely.")
# Out:
# Simulator stopped completely.
